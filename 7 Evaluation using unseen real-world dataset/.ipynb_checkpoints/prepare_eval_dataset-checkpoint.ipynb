# %%
from google.colab import drive

# %%
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
# %cd "/content/drive/My Drive/1_processing/w2v_cnn"
# Out:
# /content/drive/My Drive/1_processing/w2v_cnn

# %%
import pandas as pd
import numpy as np
import pickle
from copy import deepcopy
import yaml

# %%
with open('top10_list.pkl', 'rb') as input_file:
    top10_list = pickle.load(input_file)   
# top10_list

# %%
with open('mutated.pkl', 'rb') as input_file:
    mutated = pickle.load(input_file)   
print(mutated.columns)
mutated.shape
# Out:
# Index(['repo_count', 'task_name', 'method_description', 'mod_keys_found',
#        'mod_values_found', 'key_module_text', 'value_module_text',
#        'mod_keys_found_string', 'found_used_parameters', 'has_params',
#        'third_ast', 'third_tokens', 'token_task_names', 'descr_one_string',
#        'consistent', 'task_com', 'task_complete'],
#       dtype='object')
# (20792, 17)

# %%
mutated = mutated.drop(columns=['repo_count','mod_keys_found', 'mod_values_found', 'key_module_text', 'value_module_text','found_used_parameters', 'has_params','third_ast', 'third_tokens', 'token_task_names', 'descr_one_string','task_com'])

# %%
mutated.to_excel('evaluation_set.xlsx')

# %%
mutated.head(1)
# Out:
#    repo_count  ...                                      task_complete
# 0           0  ...  [AnsibleTask, TaskName, restart, datadog-agent...
#
# [1 rows x 17 columns]

# %%
stf = pd.read_csv('ansible_data.csv')

# %%
stf.head()
# Out:
#                                      commit  ...                                 source_code_before
# 0  3ba18e654f145b24259521a6e650387466aec5fd  ...  #ansible-playbook jenkins.yml --extra-vars "ho...
# 1  6dcdc9946903493c318dbb0b1508222da8efbfbf  ...  #ansible-playbook jenkins.yml --extra-vars "ho...
# 2  2a08d7ff220ee623415878131afd8dd4e160ee18  ...  #ansible-playbook jenkins.yml --extra-vars "ho...
# 3  c2eabaaaf1d4985e23060b23538fa3ae6fb26dc9  ...  #ansible-playbook jenkins.yml --extra-vars "ho...
# 4  cabb8c12709d8ae5329f21200183b0821e8c93c1  ...  #ansible-playbook jenkins.yml --extra-vars "ho...
#
# [5 rows x 7 columns]

# %%
type(yaml.load(stf['source_code_after'][0]))
# Out:
# list

# %%
stf2 = deepcopy(stf)

# %%
def yaml_to_dict(text):

  task_list = []

  try:

    task_list = list(yaml.load(text))

  except:
    pass

  return task_list

# %%
stf2['tasks_list_dicts'] = stf2['source_code_before'].apply(lambda x: yaml_to_dict(x))

# %%
stf2.shape
# Out:
# (3387, 8)

# %%
stf3 = deepcopy(stf2)

# %%
stf3 = stf3[stf3['tasks_list_dicts'].map(lambda d: len(d)) > 0]
stf3.shape
# Out:
# (3366, 8)

# %%
tasks_lst = []
for tsks in stf3['tasks_list_dicts']:
  for tsk in tsks:
     tasks_lst.append(tsk)

# %%
tasks_lst[1700].keys()
# Out:
# dict_keys(['block', 'when'])

# %%
for t in tasks_lst:
  if type(t) != dict:
    print(t)
# Out:
# named_config_views
# ansible_user
# ansible_become
# osp_volumes
# osp_security_groups
# osp_instances

# %%
len(tasks_lst)
# Out:
# 31699

# %%
tasks_lst = [tsk for tsk in tasks_lst if type(tsk) == dict ]

# %%
len(tasks_lst)
# Out:
# 31693

# %%
set(list(tasks_lst[19].keys()))
# Out:
# {'file', 'name'}

# %%
if list(set(list(tasks_lst[19].keys())) & set(top10_list)):
  print('yes')
# Out:
# yes

# %%
top_stf_tsk_list = [tsk for tsk in tasks_lst if list(set(tsk.keys()) & set(top10_list))]

# %%
len(top_stf_tsk_list)
# Out:
# 16928

# %%
top_stf_tsk_list[0]
# Out:
# {'copy': 'src=download-jdk7.sh dest=/tmp mode=0555',
#  'name': 'Copy download JDK7 script'}

# %%
# dftsk_stf = pd.DataFrame(top_stf_tsk_list, columns =['tasks'])

# %%
mted = deepcopy(mutated.head(10396))

# %%
m_tsk_names = mted['task_name'].tolist()

# %%
# Remove tasks found in both sets

# %%
clean_list = []
count = 0 
for t in top_stf_tsk_list:

  try:
    if t['name'] not in m_tsk_names:
      clean_list.append(t)
      count += 1

  except:
    pass

# %%
len(clean_list)
# Out:
# 14187

# %%
clean_list[879]
# Out:
# {'file': {'path': '/tmp/linklight', 'state': 'absent'},
#  'name': 'clean out /tmp/linklight'}

# %%
clean_tasks_df = pd.DataFrame(columns=['task_name','method_description'])

# %%
count = 0
for tskk in clean_list:
  
  task_names = {}
  task_body = {}

  task_names.update(name=tskk['name'])
  body_list = []

  for key,value in tskk.items():
    if key != 'name':
      task_body.update([(key,value)])
  
  body_list.append(task_body)
  print(body_list)

  clean_tasks_df = pd.concat([clean_tasks_df, pd.DataFrame({'task_name':task_names['name'],'method_description':body_list}, index=[0])], ignore_index = True)
  count += 1
  # if count == 1000:
  #   break
# Out:
# Streaming output truncated to the last 5000 lines.
# [{'template': {'src': 'var2.yml', 'dest': '/opt/appdata/plexguide/var2.yml', 'force': True}}]
# [{'shell': "hostname -I | awk '{print $1}'", 'register': 'ip_address'}]
# [{'shell': "hostname -I | awk '{print $1}' | sed 's/[0-9]*$/0/'", 'register': 'lan_net'}]
# [{'file': 'path={{item}} state=directory mode=0755 owner=1000 group=1000', 'with_items': ['/opt/appdata/vpn', '/opt/appdata/vpn/deluge', '/opt/appdata/vpn/deluge/config', '/opt/appdata/vpn/deluge/config/openvpn']}]
# [{'template': {'src': 'netherlands.ovpn', 'dest': '/opt/appdata/vpn/deluge/config/openvpn/netherlands.ovpn', 'force': True}}]
# [{'shell': 'rm -r  /opt/appdata/vpn/deluge/config/openvpn/*.ovpn'}]
# [{'template': {'src': '{{server.user_input}}.ovpn', 'dest': '/opt/appdata/vpn/deluge/config/openvpn/{{server.user_input}}.ovpn', 'force': True}}]
# [{'file': 'path={{item}} state=directory mode=0755 owner=1000 group=1000', 'with_items': ['/opt/appdata/vpn', '/opt/appdata/vpn/rtorrent', '/opt/appdata/vpn/rtorrent/config', '/opt/appdata/vpn/rtorrent/config/openvpn']}]
# [{'template': {'src': 'netherlands.ovpn', 'dest': '/opt/appdata/vpn/deluge/config/openvpn/netherlands.ovpn', 'force': True}}]
# [{'shell': 'rm -r  /opt/appdata/vpn/rtorrent/config/openvpn/*.ovpn'}]
# [{'template': {'src': '{{server.user_input}}.ovpn', 'dest': '/opt/appdata/vpn/rtorrent/config/openvpn/{{server.user_input}}.ovpn', 'force': True}}]
# [{'file': {'state': 'absent', 'path': '/opt/appdata/traefik/traefik.toml'}}]
# [{'file': 'path={{item}} state=directory mode=0775 owner=1000 group=1000', 'with_items': ['/opt/appdata/traefik']}]
# [{'template': {'src': 'traefik.toml', 'dest': '/opt/appdata/traefik/traefik.toml', 'force': True}, 'when': 'script.stat.exists == False'}]
# [{'shell': "hostname -I | awk '{print $1}'", 'register': 'local_ip'}]
# [{'file': 'path={{item}} state=directory mode=0775 owner=1000 group=1000', 'with_items': ['/opt/appdata/plex/database/Library/Application Support/Plex Media Server/Plug-ins']}]
# [{'shell': "hostname -I | awk '{print $1}'", 'register': 'local_ip'}]
# [{'file': 'path={{item}} state=directory mode=0775 owner=1000 group=1000', 'with_items': ['/opt/appdata/plex/database/Library/Application Support/Plex Media Server/Plug-ins']}]
# [{'file': 'path=/mnt/sab/ state=directory mode=0777 owner=1000 group=1000 recurse=true'}]
# [{'file': 'path=/mnt/sab/ state=directory mode=0777 owner=1000 group=1000 recurse=true'}]
# [{'shell': "awk '{print $1}' /tmp/program_var", 'register': 'program_var'}]
# [{'file': 'path={{item}} state=directory mode=0775 owner=1000 group=1000 recurse=true', 'with_items': ['/mnt/gdrive/plexguide/{{program_var.stdout}}']}]
# [{'shell': 'tar -zcvf /opt/appdata/{{program_var.stdout}} /mnt/gdrive/plexguide/{{program_var.stdout}}'}]
# [{'shell': "awk '{print $1}' /tmp/program_var", 'register': 'program_var'}]
# [{'file': 'path={{item}} state=directory mode=0775 owner=1000 group=1000 recurse=true', 'with_items': ['/mnt/gdrive/plexguide/backup/{{program_var.stdout}}']}]
# [{'file': {'path': '{{ item }}', 'state': 'absent'}, 'with_items': ['/mnt/gdrive/plexguide/backup/{{program_var.stdout}}.tar']}]
# [{'shell': 'tar -zcvf /mnt/gdrive/plexguide/backup/{{program_var.stdout}}.tar -C /opt/appdata/{{program_var.stdout}} .'}]
# [{'shell': "awk '{print $1}' /tmp/program_var", 'register': 'program_var'}]
# [{'file': {'path': '{{ item }}', 'state': 'absent'}, 'with_items': ['/opt/appdata/{{program_var.stdout}}.tar', '/tmp/{{program_var.stdout}}.tar'], 'ignore_errors': True}]
# [{'file': 'path={{item}} state=directory mode=0775 owner=1000 group=1000 recurse=true', 'with_items': ['/opt/appdata/{{program_var.stdout}}']}]
# [{'shell': "tar -xf '/tmp/{{program_var.stdout}}.tar' -C /opt/appdata/{{program_var.stdout}} ."}]
# [{'file': {'path': '{{ item }}', 'state': 'absent'}, 'with_items': ['/tmp/{{program_var.stdout}}']}]
# [{'shell': "awk '{print $1}' /tmp/program_var", 'register': 'program_var'}]
# [{'file': {'path': '{{ item }}', 'state': 'absent'}, 'with_items': ['/tmp/{{program_var.stdout}}.tar'], 'when': 'program-tmp.stat.exists == True'}]
# [{'file': {'path': '{{ item }}', 'state': 'absent'}, 'with_items': ['/tmp/{{program_var.stdout}}.tar'], 'when': 'program-appdata.stat.exists == True'}]
# [{'file': 'path={{item}} state=directory mode=0775 owner=1000 group=1000 recurse=true', 'with_items': ['/opt/appdata/{{program_var.stdout}}'], 'when': 'program-appdata.stat.exists == False'}]
# [{'shell': "tar -xf '/tmp/{{program_var.stdout}}.tar' -C /opt/appdata/{{program_var.stdout}} ."}]
# [{'file': {'path': '{{ item }}', 'state': 'absent'}, 'with_items': ['/tmp/{{program_var.stdout}}']}]
# [{'shell': "awk '{print $1}' /tmp/program_var", 'register': 'program_var'}]
# [{'file': {'path': '{{ item }}', 'state': 'absent'}, 'with_items': ['/tmp/{{program_var.stdout}}.tar'], 'when': 'program-tmp.stat.exists == True'}]
# [{'file': {'path': '{{ item }}', 'state': 'absent'}, 'with_items': ['/tmp/{{program_var.stdout}}.tar'], 'when': 'program-appdata.stat.exists == True'}]
# [{'file': 'path={{item}} state=directory mode=0775 owner=1000 group=1000 recurse=true', 'with_items': ['/opt/appdata/{{program_var.stdout}}'], 'when': 'program-appdata.stat.exists == False'}]
# [{'shell': "tar -xf '/tmp/{{program_var.stdout}}.tar' -C /opt/appdata/{{program_var.stdout}} ."}]
# [{'file': {'path': '{{ item }}', 'state': 'absent'}, 'with_items': ['/tmp/{{program_var.stdout}}']}]
# [{'shell': "awk '{print $1}' /tmp/program_var", 'register': 'program_var'}]
# [{'file': 'path={{item}} state=directory mode=0775 owner=1000 group=1000 recurse=true', 'with_items': ['/mnt/gdrive/plexguide/backup/{{program_var.stdout}}']}]
# [{'file': {'path': '{{ item }}', 'state': 'absent'}, 'with_items': ['/mnt/gdrive/plexguide/backup/{{program_var.stdout}}.tar']}]
# [{'shell': 'tar -zcvf /tmp/{{program_var.stdout}}.tar -C /opt/appdata/{{program_var.stdout}} .', 'when': 'programappdata = true'}]
# [{'command': "rclone copy '/tmp/{{program_var}}.tar' '/gdrive/plexguide/backup/{{backup.rclone_dest}}.tar' --stats=30s -v --transfers=4 --drive-chunk-size=32M'", 'when': 'programappdata = true'}]
# [{'file': {'path': '{{ item }}', 'state': 'absent'}, 'with_items': ['/mnt/gdrive/plexguide/backup/{{program_var.stdout}}']}]
# [{'shell': "awk '{print $1}' /tmp/program_var", 'register': 'program_var'}]
# [{'file': 'path={{item}} state=directory mode=0775 owner=1000 group=1000 recurse=true', 'with_items': ['/mnt/gdrive/plexguide/backup/{{program_var.stdout}}']}]
# [{'file': {'path': '{{ item }}', 'state': 'absent'}, 'with_items': ['/mnt/gdrive/plexguide/backup/{{program_var.stdout}}.tar']}]
# [{'shell': 'tar -zcvf /tmp/{{program_var.stdout}}.tar -C /opt/appdata/{{program_var.stdout}} .', 'when': 'programappdata = true'}]
# [{'command': "rclone copy '/tmp/{{program_var}}.tar' '/gdrive/plexguide/backup/{{backup.rclone_dest}}.tar' --stats=30s -v --transfers=4 --drive-chunk-size=32M'", 'when': 'programappdata = true'}]
# [{'file': {'path': '{{ item }}', 'state': 'absent'}, 'with_items': ['/mnt/gdrive/plexguide/backup/{{program_var.stdout}}']}]
# [{'shell': "awk '{print $1}' /tmp/program_var", 'register': 'program_var'}]
# [{'file': 'path={{item}} state=directory mode=0775 owner=1000 group=1000 recurse=true', 'with_items': ['/mnt/gdrive/plexguide/backup/{{program_var.stdout}}']}]
# [{'file': {'path': '{{ item }}', 'state': 'absent'}, 'with_items': ['/mnt/gdrive/plexguide/backup/{{program_var.stdout}}.tar']}]
# [{'shell': 'tar -zcvf /tmp/{{program_var.stdout}}.tar -C /opt/appdata/{{program_var.stdout}} .', 'when': 'programappdata = true'}]
# [{'command': "rclone copy '/tmp/{{program_var}}.tar' '/gdrive/plexguide/backup/{{program_var}.tar' --stats=15s -v --transfers=4 --drive-chunk-size=32M'", 'when': 'programappdata = true'}]
# [{'file': {'path': '{{ item }}', 'state': 'absent'}, 'with_items': ['/mnt/gdrive/plexguide/backup/{{program_var.stdout}}']}]
# [{'shell': "awk '{print $1}' /tmp/program_var", 'register': 'program_var'}]
# [{'file': 'path={{item}} state=directory mode=0775 owner=1000 group=1000 recurse=true', 'with_items': ['/mnt/gdrive/plexguide/backup/{{program_var.stdout}}']}]
# [{'file': {'path': '{{ item }}', 'state': 'absent'}, 'with_items': ['/mnt/gdrive/plexguide/backup/{{program_var.stdout}}.tar']}]
# [{'shell': 'tar -zcvf /tmp/{{program_var.stdout}}.tar -C /opt/appdata/{{program_var.stdout}} .', 'when': 'programappdata = true'}]
# [{'command': "rclone copy '/tmp/{{program_var}}.tar' '/gdrive/plexguide/backup/{{program_var}.tar' --stats=15s -v --transfers=4 --drive-chunk-size=32M", 'when': 'programappdata = true'}]
# [{'file': {'path': '{{ item }}', 'state': 'absent'}, 'with_items': ['/mnt/gdrive/plexguide/backup/{{program_var.stdout}}']}]
# [{'shell': "awk '{print $1}' /tmp/program_var", 'register': 'program_var'}]
# [{'file': {'path': '{{ item }}', 'state': 'absent'}, 'with_items': ['/mnt/gdrive/plexguide/backup/{{program_var.stdout}}.tar'], 'when': 'programappdata.stat.exists == True'}]
# [{'shell': 'tar -zcvf /tmp/{{program_var.stdout}}.tar -C /opt/appdata/{{program_var.stdout}} .', 'when': 'programappdata.stat.exists == True'}]
# [{'shell': 'rclone copy /tmp/{{program_var}}.tar gdrive:/plexguide/backup -v --checksum --drive-chunk-size=64M', 'when': 'programappdata.stat.exists == True'}]
# [{'shell': "awk '{print $1}' /tmp/program_var", 'register': 'program_var'}]
# [{'file': {'path': '{{ item }}', 'state': 'absent'}, 'with_items': ['/tmp/{{program_var.stdout}}.tar'], 'when': 'programtmp.stat.exists == True'}]
# [{'file': {'path': '{{ item }}', 'state': 'absent'}, 'with_items': ['/tmp/{{program_var.stdout}}.tar'], 'when': 'programtmp.stat.exists == True'}]
# [{'file': {'path': '{{ item }}', 'state': 'absent'}, 'with_items': ['/opt/appdata/{{program_var.stdout}}.tar'], 'when': 'programappdata.stat.exists == True'}]
# [{'file': 'path={{item}} state=directory mode=0775 owner=1000 group=1000 recurse=true', 'with_items': ['/opt/appdata/{{program_var.stdout}}'], 'when': 'programappdata.stat.exists == False'}]
# [{'shell': "tar -xf '/tmp/{{program_var.stdout}}.tar' -C /opt/appdata/{{program_var.stdout}} .", 'when': 'programtmp.stat.exists == True'}]
# [{'file': {'path': '{{ item }}', 'state': 'absent'}, 'with_items': ['/tmp/{{program_var.stdout}}']}]
# [{'shell': "awk '{print $1}' /tmp/program_var", 'register': 'program_var'}]
# [{'file': {'path': '{{ item }}', 'state': 'absent'}, 'with_items': ['/tmp/{{program_var.stdout}}.tar'], 'when': 'programtmp.stat.exists == True'}]
# [{'file': {'path': '{{ item }}', 'state': 'absent'}, 'with_items': ['/tmp/{{program_var.stdout}}.tar'], 'when': 'programtmp.stat.exists == True'}]
# [{'file': {'path': '{{ item }}', 'state': 'absent'}, 'with_items': ['/opt/appdata/{{program_var.stdout}}.tar'], 'when': 'programappdata.stat.exists == True'}]
# [{'file': 'path={{item}} state=directory mode=0775 owner=1000 group=1000 recurse=true', 'with_items': ['/opt/appdata/{{program_var.stdout}}'], 'when': 'programappdata.stat.exists == False'}]
# [{'shell': "tar -xf '/tmp/{{program_var.stdout}}.tar' -C /opt/appdata/{{program_var.stdout}} .", 'when': 'programtmp.stat.exists == True'}]
# [{'file': {'path': '{{ item }}', 'state': 'absent'}, 'with_items': ['/tmp/{{program_var.stdout}}']}]
# [{'shell': "awk '{print $1}' /tmp/program_var", 'register': 'program_var'}]
# [{'file': {'path': '{{ item }}', 'state': 'absent'}, 'with_items': ['/tmp/{{program_var.stdout}}.tar'], 'when': 'programtmp.stat.exists == True'}]
# [{'file': {'path': '{{ item }}', 'state': 'absent'}, 'with_items': ['/tmp/{{program_var.stdout}}.tar'], 'when': 'programtmp.stat.exists == True'}]
# [{'file': {'path': '{{ item }}', 'state': 'absent'}, 'with_items': ['/opt/appdata/{{program_var.stdout}}.tar'], 'when': 'programappdata.stat.exists == True'}]
# [{'file': 'path={{item}} state=directory mode=0775 owner=1000 group=1000 recurse=true', 'with_items': ['/opt/appdata/{{program_var.stdout}}'], 'when': 'programappdata.stat.exists == False'}]
# [{'shell': "tar -xf '/tmp/{{program_var.stdout}}.tar' -C /opt/appdata/{{program_var.stdout}} .", 'when': 'programtmp.stat.exists == True'}]
# [{'file': {'path': '{{ item }}', 'state': 'absent'}, 'with_items': ['/tmp/{{program_var.stdout}}']}]
# [{'shell': "awk '{print $1}' /tmp/program_var", 'register': 'program_var'}]
# [{'file': {'path': '{{ item }}', 'state': 'absent'}, 'with_items': ['/tmp/{{program_var.stdout}}.tar'], 'when': 'programtmp.stat.exists == True'}]
# [{'file': {'path': '{{ item }}', 'state': 'absent'}, 'with_items': ['/tmp/{{program_var.stdout}}.tar'], 'when': 'programtmp.stat.exists == True'}]
# [{'file': {'path': '{{ item }}', 'state': 'absent'}, 'with_items': ['/opt/appdata/{{program_var.stdout}}.tar'], 'when': 'programappdata.stat.exists == True'}]
# [{'file': 'path={{item}} state=directory mode=0775 owner=1000 group=1000 recurse=true', 'with_items': ['/opt/appdata/{{program_var.stdout}}'], 'when': 'programappdata.stat.exists == False'}]
# [{'shell': "tar -xf '/tmp/{{program_var.stdout}}.tar' -C /opt/appdata/{{program_var.stdout}} .", 'when': 'programtmp.stat.exists == True'}]
# [{'file': {'path': '{{ item }}', 'state': 'absent'}, 'with_items': ['/tmp/{{program_var.stdout}}']}]
# [{'file': 'path={{item}} state=directory mode=0775 owner=1000 group=1000 recurse=true', 'with_items': ['/opt/appdata/plexguide/cleaner']}]
# [{'template': {'src': 'config.json.js2', 'dest': '/opt/appdata/plexguide/cleaner/config.json', 'force': True}, 'when': 'cleaner_config.stat.exists == False'}]
# [{'file': {'path': '/opt/appdata/plexguide/cleaner/cleaner.py', 'mode': 'a+x'}}]
# [{'file': 'path=/opt/appdata/plexguide/cleaner state=directory owner={{user}} group={{user}} recurse=yes'}]
# [{'template': {'src': 'cleaner.service.js2', 'dest': '/etc/systemd/system/cleaner.service', 'force': True}, 'when': 'cleaner_service.stat.exists == False'}]
# [{'file': 'path={{item}} state=directory mode=0775 owner=1000 group=1000 recurse=true', 'with_items': ['/opt/appdata/plexguide/cleaner']}]
# [{'shell': 'git clone https://github.com/Admin9705/unionfs_cleaner.git /opt/appdata/plexguide/cleaner', 'when': 'programappdata.stat.exists == True'}]
# [{'template': {'src': 'config.json.js2', 'dest': '/opt/appdata/plexguide/cleaner/config.json', 'force': True}, 'when': 'cleaner_config.stat.exists == False'}]
# [{'file': {'path': '/opt/appdata/plexguide/cleaner/cleaner.py', 'mode': 'a+x'}}]
# [{'file': 'path=/opt/appdata/plexguide/cleaner state=directory owner={{user}} group={{user}} recurse=yes'}]
# [{'template': {'src': 'cleaner.service.js2', 'dest': '/etc/systemd/system/cleaner.service', 'force': True}, 'when': 'cleaner_service.stat.exists == False'}]
# [{'file': {'state': 'absent', 'path': '/opt/appdata/traefik/traefik.toml'}, 'tags': ['redirect']}]
# [{'file': {'state': 'absent', 'path': '/opt/appdata/traefik/traefik.toml'}, 'tags': ['redirect']}]
# [{'file': 'path={{item}} state=directory mode=0775 owner=1000 group=1000', 'with_items': ['/opt/appdata/traefik']}]
# [{'template': {'src': 'traefik.toml', 'dest': '/opt/appdata/traefik/traefik.toml', 'force': True, 'owner': 1000, 'group': 1000}, 'tags': ['redirect']}]
# [{'shell': "awk '{print $1}' /tmp/program_var", 'register': 'program_var'}]
# [{'shell': 'echo \'echo "{{program_var.stdout}}" > /tmp/program_var\' > /opt/appdata/plexguide/cron/{{program_var.stdout}}'}]
# [{'shell': 'echo "ansible-playbook /opt/plexguide/ansible/plexguide.yml --tags {{program_var.stdout}}" >> /opt/appdata/plexguide/cron/{{program_var.stdout}}'}]
# [{'shell': "hostname -I | awk '{print $1}'", 'register': 'local_ip'}]
# [{'shell': "awk '{print $1}' /tmp/plextag", 'register': 'plextag_var'}]
# [{'file': 'path={{item}} state=directory mode=0775 owner=1000 group=1000', 'with_items': ['/opt/transcodes']}]
# [{'file': 'path={{item}} state=directory mode=0775 owner=1000 group=1000', 'with_items': ['/opt/appdata/plex/database/Library/Application Support/Plex Media Server/Plug-ins']}]
# [{'shell': "awk '{print $1}' /opt/appdata/plexguide/pushapp", 'register': 'app_var', 'ignore_errors': True}]
# [{'shell': "awk '{print $1}' /opt/appdata/plexguide/pushuser", 'register': 'user_var', 'ignore_errors': True}]
# [{'file': 'path={{item}} state=directory mode=0775 owner=1000 group=1000', 'with_items': ['/opt/appdata/plexguide']}]
# [{'file': {'state': 'absent', 'path': ['/opt/appdata/plexguide/var.yml']}}]
# [{'template': {'src': 'var.yml', 'dest': '/opt/appdata/plexguide/var.yml', 'force': True}}]
# [{'shell': "awk '{print $1}' /tmp/domain", 'register': 'domain_var', 'tags': ['domain']}]
# [{'shell': "awk '{print $1}' /tmp/email", 'register': 'email_var', 'tags': ['domain']}]
# [{'shell': "hostname -I | awk '{print $1}'", 'register': 'ip_address'}]
# [{'shell': "hostname -I | awk '{print $1}' | sed 's/[0-9]*$/0/'", 'register': 'lan_net'}]
# [{'file': 'path={{item}} state=directory mode=0775 owner={{user}} group={{user}} recurse=true', 'with_items': ['/opt/plex_autoscan']}]
# [{'shell': 'pwgen 32 1', 'register': 'plex_autoscan_pass', 'when': 'plex_autoscan_config.stat.exists == False'}]
# [{'template': {'src': 'config.json.js2', 'dest': '/opt/plex_autoscan/config/config.json', 'force': True}, 'when': 'plex_autoscan_config.stat.exists == False'}]
# [{'file': {'path': '/opt/plex_autoscan/scan.py', 'mode': 'a+x'}}]
# [{'file': 'path=/opt/plex_autoscan state=directory owner={{user}} group={{user}} recurse=yes'}]
# [{'template': {'src': 'plex_autoscan.service.js2', 'dest': '/etc/systemd/system/plex_autoscan.service', 'force': True}, 'when': 'plex_autoscan_service.stat.exists == False'}]
# [{'file': {'state': 'absent', 'path': '/opt/appdata/clean'}}]
# [{'become_user': 'root', 'shell': 'git clone https://github.com/Admin9705/clean'}]
# [{'become_user': 'root', 'shell': 'python3 -m pip install -r /opt/appdata/clean/requirements.txt'}]
# [{'template': {'src': 'config.js2', 'dest': '/opt/appdata/clean/config.json', 'force': True}}]
# [{'file': {'state': 'absent', 'path': '/opt/appdata/clean'}}]
# [{'become_user': 'root', 'shell': 'git clone https://github.com/Admin9705/clean'}]
# [{'become_user': 'root', 'shell': 'python3 -m pip install -r /opt/appdata/clean/requirements.txt'}]
# [{'template': {'src': 'config.js2', 'dest': '/opt/appdata/clean/config.json', 'force': True}}]
# [{'file': {'state': 'absent', 'path': '/opt/appdata/clean'}}]
# [{'become_user': 'root', 'shell': 'git clone https://github.com/Admin9705/clean /opt/appdata/clean'}]
# [{'become_user': 'root', 'shell': 'python3 -m pip install -r /opt/appdata/clean/requirements.txt'}]
# [{'template': {'src': 'config.js2', 'dest': '/opt/appdata/clean/config.json', 'force': True}}]
# [{'file': 'path=/mnt/nzbget/ state=directory mode=0775 owner=1000 group=1000 recurse=true'}]
# [{'file': 'path=/mnt/nzbget/ state=directory mode=0775 owner=1000 group=1000 recurse=true'}]
# [{'file': 'path=/mnt/nzbget/ state=directory mode=0775 owner=1000 group=1000 recurse=true'}]
# [{'file': {'state': 'absent', 'path': '/opt/appdata/traefik/traefik.toml'}}]
# [{'file': 'path={{item}} state=directory mode=0775 owner=1000 group=1000', 'with_items': ['/opt/appdata/traefik'], 'tags': ['main']}]
# [{'template': {'src': 'traefik.toml.on', 'dest': '/opt/appdata/traefik/traefik.toml', 'force': True, 'owner': 1000, 'group': 1000}, 'tags': ['redirecton']}]
# [{'template': {'src': 'traefik.toml.off', 'dest': '/opt/appdata/traefik/traefik.toml', 'force': True, 'owner': 1000, 'group': 1000}, 'tags': ['redirectoff']}]
# [{'file': 'path=/mnt/nzbget/ state=directory mode=0775 owner=1000 group=1000 recurse=true'}]
# [{'file': 'path=/mnt/nzbget/ state=directory mode=0775 owner=1000 group=1000 recurse=true'}]
# [{'file': {'state': 'absent', 'path': '/opt/appdata/traefik/traefik.toml'}}]
# [{'file': 'path={{item}} state=directory mode=0775 owner=1000 group=1000', 'with_items': ['/opt/appdata/traefik']}]
# [{'template': {'src': 'traefik.toml', 'dest': '/opt/appdata/traefik/traefik.toml', 'force': True}, 'when': 'config.stat.exists == False'}]
# [{'copy': {'src': '/etc/sysctl.conf', 'dest': '/opt/appdata/plexguide/sysctl.conf'}, 'when': 'sysctl.stat.exists == False'}]
# [{'copy': {'src': '/opt/appdata/plexguide/sysctl.conf', 'dest': '/etc/sysctl.conf'}, 'when': 'sysctl.stat.exists == True'}]
# [{'shell': 'sysctl -e -p'}]
# [{'file': 'path=/opt/appdata/deluge/config state=directory mode=0775 owner=1000 group=1000 recurse=true'}]
# [{'template': {'src': 'noseed.conf', 'dest': '/opt/appdata/deluge/config/label.conf', 'force': True}, 'tags': ['noseed']}]
# [{'file': 'path=/opt/appdata/deluge/config state=directory mode=0775 owner=1000 group=1000 recurse=true'}]
# [{'template': {'src': 'noseed.conf', 'dest': '/opt/appdata/deluge/config/label.conf', 'force': True}, 'tags': ['noseed']}]
# [{'copy': 'src=daemon.json dest=/etc/docker/daemon.json force=yes mode=0775', 'when': 'docker_daemon.stat.exists == False'}]
# [{'file': 'path=/etc/systemd/system/docker.service.d state=directory mode=0775', 'when': 'docker_override.stat.exists == False'}]
# [{'copy': 'src=override.conf dest=/etc/systemd/system/docker.service.d/override.conf force=yes mode=0775'}]
# [{'copy': 'src=daemon.json dest=/etc/docker/daemon.json force=yes mode=0775', 'when': 'docker_daemon.stat.exists == False'}]
# [{'file': 'path=/etc/systemd/system/docker.service.d state=directory mode=0775', 'when': 'docker_override.stat.exists == False'}]
# [{'copy': 'src=override.conf dest=/etc/systemd/system/docker.service.d/override.conf force=yes mode=0775'}]
# [{'file': {'state': 'absent', 'path': '/opt/appdata/traefik/traefik.toml'}}]
# [{'shell': 'cat /var/plexguide/test', 'register': 'foo_result', 'ignore_errors': True}]
# [{'file': 'path={{item}} state=directory mode=0775 owner=1000 group=1000', 'with_items': ['/opt/appdata/traefik']}]
# [{'template': {'src': 'traefik.toml', 'dest': '/opt/appdata/traefik/traefik.toml', 'force': True, 'owner': 1000, 'group': 1000}}]
# [{'file': {'state': 'absent', 'path': '/opt/appdata/traefik/traefik.toml'}}]
# [{'file': 'path={{item}} state=directory mode=0775 owner=1000 group=1000', 'with_items': ['/opt/appdata/traefik', '/opt/appdata/traefik/acme']}]
# [{'template': {'src': 'traefik.toml', 'dest': '/opt/appdata/traefik/traefik.toml', 'force': True, 'owner': 1000, 'group': 1000}}]
# [{'template': {'src': 'acme.json', 'dest': '/opt/appdata/traefik/acme/acme.json', 'force': True, 'owner': 1000, 'group': 1000}}]
# [{'shell': 'cat /var/plexguide/traefik.provider', 'register': 'provider', 'ignore_errors': True}]
# [{'shell': 'cat /var/plexguide/traefik.var1', 'register': 'var1', 'ignore_errors': True}]
# [{'shell': 'cat /var/plexguide/traefik.var2', 'register': 'var2', 'ignore_errors': True}]
# [{'shell': 'cat /var/plexguide/traefik.var3', 'register': 'var3', 'ignore_errors': True}]
# [{'shell': 'cat /var/plexguide/traefik.var4', 'register': 'var4', 'ignore_errors': True}]
# [{'file': {'state': 'absent', 'path': '/opt/appdata/traefik/traefik.toml'}}]
# [{'file': 'path={{item}} state=directory mode=0775 owner=1000 group=1000', 'with_items': ['/opt/appdata/traefik', '/opt/appdata/traefik/acme']}]
# [{'template': {'src': 'traefik.toml', 'dest': '/opt/appdata/traefik/traefik.toml', 'force': True, 'owner': 1000, 'group': 1000}}]
# [{'template': {'src': 'acme.json', 'dest': '/opt/appdata/traefik/acme/acme.json', 'force': True, 'mode': 384, 'owner': 1000, 'group': 1000}}]
# [{'shell': 'cat /var/plexguide/traefik.provider', 'register': 'provider', 'ignore_errors': True}]
# [{'shell': 'cat /var/plexguide/traefik.var1', 'register': 'var1', 'ignore_errors': True}]
# [{'shell': 'cat /var/plexguide/traefik.var2', 'register': 'var2', 'ignore_errors': True}]
# [{'shell': 'cat /var/plexguide/traefik.var3', 'register': 'var3', 'ignore_errors': True}]
# [{'shell': 'cat /var/plexguide/traefik.var4', 'register': 'var4', 'ignore_errors': True}]
# [{'shell': "hostname -I | awk '{print $1}'", 'register': 'local_ip'}]
# [{'shell': "awk '{print $1}' /tmp/plextag", 'register': 'plextag_var'}]
# [{'shell': 'cat /tmp/plexurl', 'register': 'plex_tmpurl'}]
# [{'shell': 'cat /tmp/plextoken', 'register': 'plextoken_var'}]
# [{'file': 'path={{item}} state=directory mode=0775 owner=1000 group=1000', 'with_items': ['/opt/transcodes']}]
# [{'file': 'path={{item}} state=directory mode=0775 owner=1000 group=1000', 'with_items': ['/opt/appdata/plex/database/Library/Application Support/Plex Media Server/Plug-ins']}]
# [{'file': {'path': '/opt/appdata/scan/Logs/Plex Media Server', 'state': 'directory', 'mode': 509, 'owner': '{{user}}', 'group': '{{user}}'}}]
# [{'file': 'path={{item}} state=directory mode=0775 owner=1000 group=1000 recurse=true', 'with_items': ['{{path.stdout}}/move/audiobooks', '{{path.stdout}}/move/podcasts']}]
# [{'shell': 'cat /var/plexguide/plex.library.json', 'register': 'pgjson', 'ignore_errors': True}]
# [{'shell': 'cat /var/plexguide/pgdupes.autodelete2.json', 'register': 'pgauto', 'ignore_errors': True}]
# [{'file': 'path={{item}} state=directory mode=0775 owner=1000 group=1000 recurse=yes', 'with_items': ['/opt/appdata/pgdupes']}]
# [{'template': {'src': 'config.json.js2', 'dest': '/opt/appdata/pgdupes/config.json', 'force': True}}]
# [{'file': {'path': '/opt/appdata/pgdupes/plexdupes.py', 'mode': 'a+x'}}]
# [{'file': 'path=/opt/appdata/pgdupes state=directory owner=1000 group=1000 recurse=yes'}]
# [{'file': {'src': '/opt/appdata/pgdupes/plexdupes.py', 'dest': '/usr/local/bin/pgdupes', 'state': 'link'}}]
# [{'shell': 'cat /var/plexguide/api.sonarr', 'register': 'apis', 'ignore_errors': True}]
# [{'shell': 'cat /var/plexguide/api.radarr', 'register': 'apir', 'ignore_errors': True}]
# [{'shell': 'cat /var/plexguide/api.trakkey', 'register': 'key', 'ignore_errors': True}]
# [{'shell': 'cat /var/plexguide/pgtrak.radarr', 'register': 'radarr', 'ignore_errors': True}]
# [{'shell': 'cat /var/plexguide/pgtrak.sonarr', 'register': 'sonarr', 'ignore_errors': True}]
# [{'file': 'path={{item}} state=directory mode=0775 owner=1000 group=1000 recurse=yes', 'with_items': ['/opt/appdata/pgtrak']}]
# [{'template': {'src': 'config.json.js2', 'dest': '/opt/appdata/pgtrak/config.json', 'force': True}}]
# [{'file': {'path': '/opt/appdata/pgtrak/traktarr.py', 'mode': 'a+x'}}]
# [{'file': 'path=/opt/appdata/pgtrak state=directory owner=1000 group=1000 recurse=yes'}]
# [{'file': {'src': '/opt/appdata/pgtrak/traktarr.py', 'dest': '/usr/local/bin/pgtrak', 'state': 'link'}}]
# [{'template': {'src': 'pgtrak.service.js2', 'dest': '/etc/systemd/system/pgtrak.service', 'force': True}, 'when': 'pgtrak_service.stat.exists == False'}]
# [{'shell': 'cat /var/plexguide/plex.library.json', 'register': 'pgjson', 'ignore_errors': True}]
# [{'shell': 'cat /var/plexguide/pgdupes.autodelete2.json', 'register': 'pgauto', 'ignore_errors': True}]
# [{'file': 'path={{item}} state=directory mode=0775 owner=1000 group=1000 recurse=yes', 'with_items': ['/opt/appdata/pgdupes']}]
# [{'template': {'src': 'config.json.js2', 'dest': '/opt/appdata/pgdupes/config.json', 'force': True}}]
# [{'file': {'path': '/opt/appdata/pgdupes/plexdupes.py', 'mode': 'a+x'}}]
# [{'file': 'path=/opt/appdata/pgdupes state=directory owner=1000 group=1000 recurse=yes'}]
# [{'file': {'src': '/opt/appdata/pgdupes/plexdupes.py', 'dest': '/usr/local/bin/pgdupes', 'state': 'link'}}]
# [{'shell': 'cat /var/plexguide/plex.library.json', 'register': 'pgjson', 'ignore_errors': True}]
# [{'shell': 'cat /var/plexguide/pgdupes.autodelete2.json', 'register': 'pgauto', 'ignore_errors': True}]
# [{'file': 'path={{item}} state=directory mode=0775 owner=1000 group=1000 recurse=yes', 'with_items': ['/opt/appdata/pgdupes']}]
# [{'template': {'src': 'config.json.js2', 'dest': '/opt/appdata/pgdupes/config.json', 'force': True}}]
# [{'file': {'path': '/opt/appdata/pgdupes/plexdupes.py', 'mode': 'a+x'}}]
# [{'file': 'path=/opt/appdata/pgdupes state=directory owner=1000 group=1000 recurse=yes'}]
# [{'file': {'src': '/opt/appdata/pgdupes/plexdupes.py', 'dest': '/usr/local/bin/pgdupes', 'state': 'link'}}]
# [{'shell': 'cat /var/plexguide/plex.library.json', 'register': 'pgjson', 'ignore_errors': True}]
# [{'shell': 'cat /var/plexguide/pgdupes.autodelete2.json', 'register': 'pgauto', 'ignore_errors': True}]
# [{'file': 'path={{item}} state=directory mode=0775 owner=1000 group=1000 recurse=yes', 'with_items': ['/opt/appdata/pgdupes']}]
# [{'template': {'src': 'config.json.js2', 'dest': '/opt/appdata/pgdupes/config.json', 'force': True}}]
# [{'file': {'path': '/opt/appdata/pgdupes/plexdupes.py', 'mode': 'a+x'}}]
# [{'file': 'path=/opt/appdata/pgdupes state=directory owner=1000 group=1000 recurse=yes'}]
# [{'file': {'src': '/opt/appdata/pgdupes/plexdupes.py', 'dest': '/usr/local/bin/pgdupes', 'state': 'link'}}]
# [{'file': 'path={{item}} state=directory mode=0775 owner=1000 group=1000 recurse=true', 'with_items': ['{{path.stdout}}/move/audiobooks', '{{path.stdout}}/move/podcasts']}]
# [{'shell': 'cat /var/plexguide/image.{{role_name}}', 'register': 'image', 'ignore_errors': True}]
# [{'shell': 'cat /var/plexguide/image.{{role_name}}.path', 'register': 'pathplus', 'ignore_errors': True}]
# [{'shell': "awk '{print $1}' /tmp/program_var", 'register': 'program_var', 'ignore_errors': True}]
# [{'shell': "awk '{print $1}' /tmp/cron.minute", 'register': 'minute', 'ignore_errors': True}]
# [{'shell': "awk '{print $1}' /tmp/cron.hour", 'register': 'hour', 'ignore_errors': True}]
# [{'shell': "awk '{print $1}' /tmp/cron.day", 'register': 'day', 'ignore_errors': True}]
# [{'file': 'path={{item}} state=directory mode=0775 owner=1000 group=1000', 'with_items': ['/opt/appdata/plexguide/cron'], 'ignore_errors': True}]
# [{'file': 'path={{item}} state=directory mode=0775 owner=1000 group=1000', 'with_items': ['/opt/appdata/plexguide/cron'], 'ignore_errors': True}]
# [{'shell': 'echo "ansible-playbook /opt/plexguide/ansible/plexguide.yml --tags backup" >> /opt/appdata/plexguide/cron/{{program_var.stdout}}'}]
# [{'file': 'path={{item}} state=directory mode=0775 owner=1000 group=1000', 'with_items': ['/opt/appdata/nextcloud', '/opt/appdata/nextcloud/conf', '/opt/appdata/nextcloud/data', '/opt/appdata/nextcloud/mariadb']}]
# [{'shell': 'cat /var/plexguide/tld.{{ role_name }}', 'register': 'tld', 'ignore_errors': True}]
# [{'docker_container': {'name': 'utorrent', 'state': 'absent'}, 'file': {'path': '/opt/appdata/utorrent', 'state': 'absent'}}]
# [{'template': {'src': 'utserver.conf', 'dest': '/opt/appdata/utorrent/settings/utserver.conf', 'force': True, 'mode': 509}}]
# [{'file': {'path': ['/opt/appdata/{{ item }}'], 'state': 'absent'}, 'with_items': ['utorrent', 'utorrents']}]
# [{'file': {'path': ['/opt/appdata/utorrent/{{ item }}'], 'mode': 509, 'state': 'directory'}, 'with_items': ['settings', 'data', 'active', 'autoload', 'torrents']}]
# [{'template': {'src': 'utserver.conf', 'dest': '/opt/appdata/utorrent/utserver.conf', 'force': True, 'mode': 509}}]
# [{'file': {'path': ['/opt/appdata/{{ item }}'], 'state': 'absent'}, 'with_items': ['qbittorrent']}]
# [{'file': {'path': '/opt/appdata/qbittorrent', 'mode': 509, 'state': 'directory'}}]
# [{'file': {'state': 'absent', 'path': '/opt/appdata/cloudplow'}}]
# [{'become_user': 'root', 'shell': 'git clone https://github.com/Admin9705/clean /opt/appdata/cloudplow'}]
# [{'become_user': 'root', 'shell': 'python3 -m pip install -r /opt/appdata/cloudplow/requirements.txt'}]
# [{'template': {'src': 'config.js2', 'dest': '/opt/appdata/cloudplow/config.json', 'force': True}}]
# [{'file': 'path={{item}} state=directory mode=0775 owner=1000 group=1000 recurse=yes', 'with_items': ['/opt/appdata/pgscan']}]
# [{'shell': 'cat /opt/appdata/plexguide/plextoken', 'register': 'plex_token', 'when': 'pgscan_config.stat.exists == False'}]
# [{'shell': 'pwgen 32 1', 'register': 'pgscan_pass', 'when': 'pgscan_config.stat.exists == False'}]
# [{'template': {'src': 'config.json.js2', 'dest': '/opt/appdata/pgscan/config/config.json', 'force': True}, 'when': 'pgscan_config.stat.exists == False'}]
# [{'shell': 'rclone touch gdrive:/mounted.bin'}]
# [{'file': {'path': '/opt/appdata/pgscan/scan.py', 'mode': 'a+x'}}]
# [{'file': 'path=/opt/appdata/pgscan state=directory owner=1000 group=1000 recurse=yes'}]
# [{'template': {'src': 'pgscan.service.js2', 'dest': '/etc/systemd/system/pgscan.service', 'force': True}, 'when': 'pgscan_service.stat.exists == False'}]
# [{'shell': "awk '{print $1}' /tmp/program_var", 'register': 'program_var'}]
# [{'file': {'path': '{{ item }}', 'state': 'absent'}, 'with_items': ['/mnt/gdrive/plexguide/backup/{{program_var.stdout}}.tar'], 'when': 'programappdata.stat.exists == True'}]
# [{'shell': 'rclone copy /tmp/{{program_var.stdout}}.tar gdrive:/plexguide/backup -v --checksum --drive-chunk-size=64M', 'when': 'encrypted.stat.exists == False and programappdata.stat.exists == True'}]
# [{'shell': 'rclone copy /tmp/{{program_var.stdout}}.tar gcrypt:/plexguide/backup -v --checksum --drive-chunk-size=64M', 'when': 'encrypted.stat.exists == True and programappdata.stat.exists == True'}]
# [{'shell': "awk '{print $1}' /var/plexguide/vpn.user", 'register': 'vpnuser'}]
# [{'shell': "awk '{print $1}' /var/plexguide/vpn.password", 'register': 'vpnpassword'}]
# [{'file': 'path={{item}} state=directory mode=0775 owner=1000 group=1000 recurse=true', 'with_items': ['/opt/appdata/openvpn', '/opt/appdata/openvpn/config']}]
# [{'template': {'src': 'ca.rsa.2048.crt', 'dest': '/opt/appdata/openvpn/ca.rsa.2048.crt', 'force': True}}]
# [{'template': {'src': 'crl.rsa.2048.pem', 'dest': '/opt/appdata/openvpn/crl.rsa.2048.pem', 'force': True}}]
# [{'template': {'src': 'netherlands.ovpn', 'dest': '/opt/appdata/openvpn/netherlands.ovpn', 'force': True}}]
# [{'shell': '/sbin/modprobe iptable_mangle'}]
# [{'file': {'path': '/opt/appdata/qbittorrent', 'mode': 509, 'owner': 1000, 'group': 1000, 'state': 'directory', 'recurse': True}}]
# [{'file': {'path': '/opt/appdata/qbittorrent/config', 'mode': 509, 'owner': 1000, 'group': 1000, 'state': 'directory', 'recurse': True}}]
# [{'file': {'path': '/opt/appdata/qbittorrent/torrents', 'mode': 509, 'owner': 1000, 'group': 1000, 'state': 'directory', 'recurse': True}}]
# [{'file': {'path': '{{path.stdout}}/qbittorrent', 'mode': 509, 'owner': 1000, 'group': 1000, 'state': 'directory', 'recurse': True}}]
# [{'file': {'path': '{{path.stdout}}/qbittorrent/Downloads', 'mode': 2775, 'owner': 1000, 'group': 1000, 'state': 'directory', 'recurse': True}}]
# [{'file': {'path': '{{path.stdout}}/qbittorrent/Downloads/temp', 'mode': 2775, 'owner': 1000, 'group': 1000, 'state': 'directory', 'recurse': True}}]
# [{'file': {'path': '/opt/appdata/qbittorrent', 'mode': 509, 'owner': 1000, 'group': 1000, 'state': 'directory', 'recurse': True}}]
# [{'file': {'path': '/opt/appdata/qbittorrent/config', 'mode': 509, 'owner': 1000, 'group': 1000, 'state': 'directory', 'recurse': True}}]
# [{'file': {'path': '/opt/appdata/qbittorrent/torrents', 'mode': 509, 'owner': 1000, 'group': 1000, 'state': 'directory', 'recurse': True}}]
# [{'file': {'path': '{{path.stdout}}/qbittorrent', 'mode': 509, 'owner': 1000, 'group': 1000, 'state': 'directory', 'recurse': True}}]
# [{'file': {'path': '{{path.stdout}}/qbittorrent/Downloads', 'mode': 2775, 'owner': 1000, 'group': 1000, 'state': 'directory', 'recurse': True}}]
# [{'file': {'path': '{{path.stdout}}/qbittorrent/Downloads/temp', 'mode': 2775, 'owner': 1000, 'group': 1000, 'state': 'directory', 'recurse': True}}]
# [{'shell': 'cat /var/plexguide/api.sonarr', 'register': 'apis', 'ignore_errors': True}]
# [{'shell': 'cat /var/plexguide/api.radarr', 'register': 'apir', 'ignore_errors': True}]
# [{'shell': 'cat /var/plexguide/api.trakkey', 'register': 'key', 'ignore_errors': True}]
# [{'shell': 'cat /var/plexguide/pgtrak.radarr', 'register': 'radarr', 'ignore_errors': True}]
# [{'shell': 'cat /var/plexguide/pgtrak.sonarr', 'register': 'sonarr', 'ignore_errors': True}]
# [{'file': 'path={{item}} state=directory mode=0775 owner=1000 group=1000 recurse=yes', 'with_items': ['/opt/appdata/pgtrak']}]
# [{'template': {'src': 'config.json.js2', 'dest': '/opt/appdata/pgtrak/config.json', 'force': True}}]
# [{'file': {'path': '/opt/appdata/pgtrak/traktarr.py', 'mode': 'a+x'}}]
# [{'file': 'path=/opt/appdata/pgtrak state=directory owner=1000 group=1000 recurse=yes'}]
# [{'file': {'src': '/opt/appdata/pgtrak/traktarr.py', 'dest': '/usr/local/bin/pgtrak', 'state': 'link'}}]
# [{'template': {'src': 'pgtrak.service.js2', 'dest': '/etc/systemd/system/pgtrak.service', 'force': True}, 'when': 'pgtrak_service.stat.exists == False'}]
# [{'shell': 'cat /var/plexguide/api.sonarr', 'register': 'apis', 'ignore_errors': True}]
# [{'shell': 'cat /var/plexguide/api.radarr', 'register': 'apir', 'ignore_errors': True}]
# [{'shell': 'cat /var/plexguide/pgtrak.prosonarr', 'register': 'prosonarr', 'ignore_errors': True}]
# [{'shell': 'cat /var/plexguide/pgtrak.proradarr', 'register': 'proradarr', 'ignore_errors': True}]
# [{'shell': 'cat /var/plexguide/pgtrak.client', 'register': 'client', 'ignore_errors': True}]
# [{'shell': 'cat /var/plexguide/pgtrak.secret', 'register': 'secret', 'ignore_errors': True}]
# [{'shell': 'cat /var/plexguide/pgtrak.radarr', 'register': 'radarr', 'ignore_errors': True}]
# [{'shell': 'cat /var/plexguide/pgtrak.sonarr', 'register': 'sonarr', 'ignore_errors': True}]
# [{'file': 'path={{item}} state=directory mode=0775 owner=1000 group=1000 recurse=yes', 'with_items': ['/opt/appdata/pgtrak']}]
# [{'template': {'src': 'config.json.js2', 'dest': '/opt/appdata/pgtrak/config.json', 'force': True}}]
# [{'file': {'path': '/opt/appdata/pgtrak/traktarr.py', 'mode': 'a+x'}}]
# [{'file': 'path=/opt/appdata/pgtrak state=directory owner=1000 group=1000 recurse=yes'}]
# [{'file': {'src': '/opt/appdata/pgtrak/traktarr.py', 'dest': '/usr/local/bin/pgtrak', 'state': 'link'}}]
# [{'template': {'src': 'pgtrak.service.js2', 'dest': '/etc/systemd/system/pgtrak.service', 'force': True}, 'when': 'pgtrak_service.stat.exists == False'}]
# [{'shell': 'cat /var/plexguide/pg.docker16.full', 'register': 'docversion', 'ignore_errors': True, 'tags': 'docker16'}]
# [{'shell': 'cat /var/plexguide/pg.docker16.edition', 'register': 'docedition', 'ignore_errors': True, 'tags': 'docker16'}]
# [{'shell': 'cat /var/plexguide/pg.docker18.full', 'register': 'docversion', 'ignore_errors': True, 'tags': 'docker18'}]
# [{'shell': 'cat /var/plexguide/pg.docker18.edition', 'register': 'docedition', 'ignore_errors': True, 'tags': 'docker18'}]
# [{'copy': 'src=daemon.json dest=/etc/docker/daemon.json force=yes mode=0775', 'when': 'docker_daemon.stat.exists == False', 'tags': 'docker_standard'}]
# [{'file': 'path=/etc/systemd/system/docker.service.d state=directory mode=0775', 'when': 'docker_override.stat.exists == False', 'tags': 'docker_standard'}]
# [{'copy': 'src=override.conf dest=/etc/systemd/system/docker.service.d/override.conf force=yes mode=0775', 'tags': 'docker_standard'}]
# [{'shell': 'cat /var/plexguide/pg.docker16.full', 'register': 'docversion', 'ignore_errors': True, 'tags': 'docker16'}]
# [{'shell': 'cat /var/plexguide/pg.docker16.edition', 'register': 'docedition', 'ignore_errors': True, 'tags': 'docker16'}]
# [{'shell': 'cat /var/plexguide/pg.docker18.full', 'register': 'docversion', 'ignore_errors': True, 'tags': 'docker18'}]
# [{'shell': 'cat /var/plexguide/pg.docker18.edition', 'register': 'docedition', 'ignore_errors': True, 'tags': 'docker18'}]
# [{'copy': 'src=daemon.json dest=/etc/docker/daemon.json force=yes mode=0775', 'when': 'docker_daemon.stat.exists == False', 'tags': 'docker_standard'}]
# [{'file': 'path=/etc/systemd/system/docker.service.d state=directory mode=0775', 'when': 'docker_override.stat.exists == False', 'tags': 'docker_standard'}]
# [{'copy': 'src=override.conf dest=/etc/systemd/system/docker.service.d/override.conf force=yes mode=0775', 'tags': 'docker_standard'}]
# [{'shell': "awk '{print $1}' /tmp/program_var", 'register': 'program_var', 'tags': ['backup_normal']}]
# [{'shell': 'cat /var/plexguide/server.id', 'register': 'server_id', 'tags': ['backup_normal']}]
# [{'shell': "tar --warning=no-file-removed --warning=no-file-changed --ignore-failed-read --exclude='./database/Library/Application Support/Plex Media Server/Cache/PhotoTranscoder' -zcvf /tmp/plex.tar -C /opt/appdata/plex .", 'ignore_errors': True, 'tags': ['backup_plex']}]
# [{'shell': 'rclone copy /tmp/{{program_var.stdout}}.tar gdrive:/plexguide/backup/{{server_id.stdout}} -v --checksum --drive-chunk-size=64M', 'when': 'encrypted.stat.exists == False and programappdata.stat.exists == True', 'tags': ['backup_normal']}]
# [{'shell': 'rclone copy /tmp/{{program_var.stdout}}.tar gcrypt:/plexguide/backup/{{server_id.stdout}} -v --checksum --drive-chunk-size=64M', 'when': 'encrypted.stat.exists == True and programappdata.stat.exists == True', 'tags': ['backup_normal']}]
# [{'file': {'path': '{{ item }}', 'state': 'absent'}, 'with_items': ['/tmp/{{program_var.stdout}}.tar'], 'when': 'programappdata.stat.exists == True', 'tags': ['backup_normal']}]
# [{'shell': 'cat /var/plexguide/wp.id', 'register': 'server_id'}]
# [{'shell': "echo 'wordpress-{{server_id.stdout}}'", 'register': 'wp_id'}]
# [{'shell': "echo 'wordpress-{{server_id.stdout}}-db'", 'register': 'db_id'}]
# [{'shell': 'rclone copy /tmp/{{wp_id.stdout}}.tar gdrive:/plexguide/backup/wordpress/{{server_id.stdout}} -v --checksum --drive-chunk-size=64M', 'when': 'encrypted.stat.exists == False and programappdata.stat.exists == True'}]
# [{'shell': 'rclone copy /tmp/{{wp_id.stdout}}.tar gcrypt:/plexguide/backup/wordpress/{{server_id.stdout}} -v --checksum --drive-chunk-size=64M', 'when': 'encrypted.stat.exists == True and programappdata.stat.exists == True'}]
# [{'file': {'path': '{{ item }}', 'state': 'absent'}, 'with_items': ['/tmp/{{wp_id.stdout}}.tar'], 'when': 'programappdata.stat.exists == True'}]
# [{'shell': 'cat /var/plexguide/wp.id', 'register': 'server_id'}]
# [{'shell': "echo 'wordpress-{{server_id.stdout}}'", 'register': 'wp_id'}]
# [{'shell': "echo 'wordpress-{{server_id.stdout}}-db'", 'register': 'db_id'}]
# [{'shell': 'rclone copy /tmp/{{wp_id.stdout}}.tar gdrive:/plexguide/backup/wordpress/{{server_id.stdout}} -v --checksum --drive-chunk-size=64M', 'when': 'encrypted.stat.exists == False and programappdata.stat.exists == True'}]
# [{'shell': 'rclone copy /tmp/{{wp_id.stdout}}.tar gcrypt:/plexguide/backup/wordpress/{{server_id.stdout}} -v --checksum --drive-chunk-size=64M', 'when': 'encrypted.stat.exists == True and programappdata.stat.exists == True'}]
# [{'file': {'path': '{{ item }}', 'state': 'absent'}, 'with_items': ['/tmp/{{wp_id.stdout}}.tar'], 'when': 'programappdata.stat.exists == True'}]
# [{'shell': 'cat /var/plexguide/wp.id', 'register': 'server_id'}]
# [{'shell': "echo 'wordpress-{{server_id.stdout}}'", 'register': 'wp_id'}]
# [{'shell': 'rclone copy /tmp/{{wp_id.stdout}}.tar gdrive:/plexguide/backup/wordpress/{{server_id.stdout}} -v --checksum --drive-chunk-size=64M', 'when': 'encrypted.stat.exists == False and programappdata.stat.exists == True'}]
# [{'shell': 'rclone copy /tmp/{{wp_id.stdout}}.tar gcrypt:/plexguide/backup/wordpress/{{server_id.stdout}} -v --checksum --drive-chunk-size=64M', 'when': 'encrypted.stat.exists == True and programappdata.stat.exists == True'}]
# [{'shell': 'rclone copy /tmp/{{wp_id.stdout}}-database.tar gdrive:/plexguide/backup/wordpress/{{server_id.stdout}}-database -v --checksum --drive-chunk-size=64M', 'when': 'encrypted.stat.exists == False and programappdata.stat.exists == True'}]
# [{'shell': 'rclone copy /tmp/{{wp_id.stdout}}-database.tar gcrypt:/plexguide/backup/wordpress/{{server_id.stdout}}-database -v --checksum --drive-chunk-size=64M', 'when': 'encrypted.stat.exists == True and programappdata.stat.exists == True'}]
# [{'file': {'path': '{{ item }}', 'state': 'absent'}, 'with_items': ['/tmp/{{wp_id.stdout}}.tar'], 'when': 'programappdata.stat.exists == True'}]
# [{'file': {'path': '{{ item }}', 'state': 'absent'}, 'with_items': ['/tmp/{{wp_id.stdout}}-database.tar'], 'when': 'programappdata.stat.exists == True'}]
# [{'shell': "awk '{print $1}' /tmp/program_var", 'register': 'program_var', 'tags': ['backup_normal']}]
# [{'shell': 'cat /var/plexguide/server.id', 'register': 'server_id', 'tags': ['backup_normal']}]
# [{'shell': "tar --warning=no-file-removed --warning=no-file-changed --ignore-failed-read --exclude='./database/Library/Application Support/Plex Media Server/Cache/PhotoTranscoder' -zcvf /tmp/plex.tar -C /opt/appdata/plex .", 'ignore_errors': True, 'tags': ['backup_plex']}]
# [{'shell': 'rclone copy /tmp/{{program_var.stdout}}.tar gdrive:/plexguide/backup/{{server_id.stdout}} -v --checksum --drive-chunk-size=64M', 'when': 'encrypted.stat.exists == False and programappdata.stat.exists == True', 'tags': ['backup_normal']}]
# [{'shell': 'rclone copy /tmp/{{program_var.stdout}}.tar gcrypt:/plexguide/backup/{{server_id.stdout}} -v --checksum --drive-chunk-size=64M', 'when': 'encrypted.stat.exists == True and programappdata.stat.exists == True', 'tags': ['backup_normal']}]
# [{'file': {'path': '{{ item }}', 'state': 'absent'}, 'with_items': ['/tmp/{{program_var.stdout}}.tar'], 'when': 'programappdata.stat.exists == True', 'tags': ['backup_normal']}]
# [{'shell': 'cat /var/plexguide/wp.id', 'register': 'server_id'}]
# [{'shell': "echo 'wordpress-{{server_id.stdout}}'", 'register': 'wp_id'}]
# [{'file': {'path': '{{ item }}', 'state': 'absent'}, 'with_items': ['/tmp/{{wp_id.stdout}}.tar', '/tmp/{{wp_id.stdout}}-db.tar', '/opt/appdata/wordpress/{{server_id.stdout}}-db/*', '/opt/appdata/wordpress/{{server_id.stdout}}/*'], 'ignore_errors': True}]
# [{'file': {'path': '{{ item }}', 'state': 'absent'}, 'with_items': ['/opt/appdata/{{program_var.stdout}}']}]
# [{'file': 'path={{item}} state=directory mode=0775 owner=1000 group=1000', 'with_items': ['/opt/appdata/{{program_var.stdout}}'], 'ignore_errors': True}]
# [{'file': {'path': '{{ item }}', 'state': 'absent'}, 'ignore_errors': True, 'with_items': ['/tmp/{{program_var.stdout}}.tar']}]
# [{'shell': 'cat /var/plexguide/wp.id', 'register': 'server_id'}]
# [{'shell': "echo 'wordpress-{{server_id.stdout}}'", 'register': 'wp_id'}]
# [{'file': {'path': '{{ item }}', 'state': 'absent'}, 'with_items': ['/tmp/{{wp_id.stdout}}.tar', '/tmp/{{wp_id.stdout}}-db.tar', '/opt/appdata/wordpress/{{server_id.stdout}}-db/*', '/opt/appdata/wordpress/{{server_id.stdout}}/*'], 'ignore_errors': True, 'when': 'programgdrive.stat.exists == True'}]
# [{'file': {'path': '{{ item }}', 'state': 'absent'}, 'with_items': ['/opt/appdata/{{program_var.stdout}}']}]
# [{'file': 'path={{item}} state=directory mode=0775 owner=1000 group=1000', 'with_items': ['/opt/appdata/{{program_var.stdout}}'], 'ignore_errors': True}]
# [{'file': {'path': '{{ item }}', 'state': 'absent'}, 'ignore_errors': True, 'with_items': ['/tmp/{{program_var.stdout}}.tar']}]
# [{'shell': "echo 'INFO - Ansible Role {{role_name}} Started' > /var/plexguide/pg.log && bash /opt/plexguide/scripts/log.sh"}]
# [{'file': 'path={{item}} state=directory mode=0775 owner=1000 group=1000 recurse=yes', 'with_items': ['/opt/appdata/alltube']}]
# [{'template': {'src': 'config.json.js2', 'dest': '/opt/appdata/alltube/config.json', 'force': True}}]
# [{'shell': "echo 'INFO - Ansible Role {{role_name}} Started' > /var/plexguide/pg.log && bash /opt/plexguide/scripts/log.sh"}]
# [{'file': 'path={{item}} state=directory mode=0775 owner=1000 group=1000', 'with_items': ['/opt/appdata/portainer']}]
# [{'shell': "echo 'INFO - Ansible Role {{role_name}} Started' > /var/plexguide/pg.log && bash /opt/plexguide/scripts/log.sh"}]
# [{'shell': 'bash /opt/plexguide/roles/radarr4k/menus/images.sh'}]
# [{'shell': 'cat /var/plexguide/image.{{role_name}}', 'register': 'image', 'ignore_errors': True}]
# [{'shell': 'cat /var/plexguide/extra.{{role_name}}', 'register': 'extra', 'ignore_errors': True}]
# [{'file': 'path={{item}} state=directory mode=0775 owner=1000 group=1000', 'with_items': ['/opt/appdata/{{role_name}}/mp4_automator']}]
# [{'template': {'src': 'autoProcess.ini', 'dest': '/opt/appdata/{{role_name}}/mp4_automator/autoProcess.ini', 'force': True, 'mode': 509}}]
# [{'shell': "echo 'INFO - Ansible Role {{role_name}} Completed' > /var/plexguide/pg.log && bash /opt/plexguide/scripts/log.sh"}]
# [{'shell': "echo 'INFO - Ansible Role {{role_name}} Started' > /var/plexguide/pg.log && bash /opt/plexguide/scripts/log.sh"}]
# [{'shell': 'bash /opt/plexguide/roles/radarr4k/menus/images.sh'}]
# [{'shell': 'cat /var/plexguide/image.{{role_name}}', 'register': 'image', 'ignore_errors': True}]
# [{'shell': 'cat /var/plexguide/extra.{{role_name}}', 'register': 'extra', 'ignore_errors': True}]
# [{'file': 'path={{item}} state=directory mode=0775 owner=1000 group=1000', 'with_items': ['/opt/appdata/{{role_name}}/mp4_automator']}]
# ...
# [{'shell': '{{rsync_path}} {{rsync_extra_parameters}} {{rsync_user}}@{{node_certs_generator_ip}}:{{node_certs_source}}/ca/ {{node_certs_destination}}/', 'when': ['not node_certs_generator', 'elasticsearch_xpack_security', 'not certificate_file_exists.stat.exists'], 'register': 'check_certs_permissions', 'tags': 'xpack-security'}]
# [{'shell': '/bin/rm -f {{node_certs_source}}/certs.zip*', 'when': ['node_certs_generator', 'elasticsearch_xpack_security'], 'tags': 'xpack-security'}]
# [{'template': {'src': 'cdb_lists.j2', 'dest': '/var/ossec/etc/lists/{{ item.name }}', 'owner': 'root', 'group': 'ossec', 'mode': 416}, 'no_log': True, 'register': 'wazuh_manager_cdb_lists', 'until': 'wazuh_manager_cdb_lists is succeeded', 'notify': ['rebuild cdb_lists', 'restart wazuh-manager'], 'with_items': ['{{ cdb_lists }}'], 'when': ['cdb_lists is defined', 'cdb_lists is iterable'], 'tags': ['config']}]
# [{'service': {'name': '{{ item }}', 'enabled': True, 'state': 'started'}, 'with_items': ['wazuh-manager', 'wazuh-api'], 'tags': ['config'], 'environment': {'LD_LIBRARY_PATH': '$LD_LIBRARY_PATH:/var/ossec/framework/lib'}, 'when': ["not (ansible_distribution == 'CentOS' or ansible_distribution == 'RedHat' and ansible_distribution_major_version|int < 6)"]}]
# [{'service': {'name': 'wazuh-manager', 'enabled': True, 'state': 'started'}, 'tags': ['config'], 'when': ["ansible_distribution in ['CentOS', 'RedHat'] and ansible_distribution_major_version|int < 6"]}]
# [{'shell': '{{rsync_path}} {{rsync_extra_parameters}} {{rsync_user}}@{{node_certs_generator_ip}}:{{node_certs_source}}/{{filebeat_node_name}}/ {{node_certs_destination}}/', 'when': ['not node_certs_generator', 'filebeat_xpack_security', 'not certificate_file_exists.stat.exists'], 'tags': 'xpack-security'}]
# [{'shell': '{{rsync_path}} {{rsync_extra_parameters}} {{rsync_user}}@{{node_certs_generator_ip}}:{{node_certs_source}}/ca/ {{node_certs_destination}}/', 'when': ['not node_certs_generator', 'filebeat_xpack_security', 'not certificate_file_exists.stat.exists'], 'register': 'check_certs_permissions', 'tags': 'xpack-security'}]
# [{'template': {'src': 'cdb_lists.j2', 'dest': '/var/ossec/etc/lists/{{ item.name }}', 'owner': 'root', 'group': 'ossec', 'mode': 416}, 'no_log': True, 'register': 'wazuh_manager_cdb_lists', 'until': 'wazuh_manager_cdb_lists is succeeded', 'notify': ['rebuild cdb_lists', 'restart wazuh-manager'], 'with_items': ['{{ cdb_lists }}'], 'when': ['cdb_lists is defined', 'cdb_lists is iterable'], 'tags': ['config']}]
# [{'service': {'name': '{{ item }}', 'enabled': True, 'state': 'started'}, 'with_items': ['wazuh-manager', 'wazuh-api'], 'tags': ['config'], 'environment': {'LD_LIBRARY_PATH': '$LD_LIBRARY_PATH:/var/ossec/framework/lib'}, 'when': ["not (ansible_distribution == 'CentOS' or ansible_distribution == 'RedHat' and ansible_distribution_major_version|int < 6)"]}]
# [{'service': {'name': 'wazuh-manager', 'enabled': True, 'state': 'started'}, 'tags': ['config'], 'when': ["ansible_distribution in ['CentOS', 'RedHat'] and ansible_distribution_major_version|int < 6"]}]
# [{'shell': '/usr/share/elasticsearch/bin/elasticsearch-certutil cert ca --pem --in {{node_certs_source}}/instances.yml --out {{node_certs_source}}/certs.zip', 'when': ['node_certs_generator', 'elasticsearch_xpack_security', 'not xpack_certs_zip.stat.exists', 'not certificate_file_exists.stat.exists'], 'register': 'certs_file_generated', 'tags': 'xpack-security'}]
# [{'shell': '{{rsync_path}} {{rsync_extra_parameters}} {{rsync_user}}@{{node_certs_generator_ip}}:{{node_certs_source}}/{{elasticsearch_node_name}}/ {{node_certs_destination}}/', 'when': ['not node_certs_generator', 'elasticsearch_xpack_security', 'not certificate_file_exists.stat.exists'], 'tags': 'xpack-security'}]
# [{'shell': '{{rsync_path}} {{rsync_extra_parameters}} {{rsync_user}}@{{node_certs_generator_ip}}:{{node_certs_source}}/ca/ {{node_certs_destination}}/', 'when': ['not node_certs_generator', 'elasticsearch_xpack_security', 'not certificate_file_exists.stat.exists'], 'register': 'check_certs_permissions', 'tags': 'xpack-security'}]
# [{'shell': '/bin/rm -f {{node_certs_source}}/certs.zip*', 'when': ['node_certs_generator', 'elasticsearch_xpack_security'], 'tags': 'xpack-security'}]
# [{'service': 'name=elasticsearch enabled=yes'}]
# [{'service': 'name=elasticsearch state=started', 'ignore_errors': True}]
# [{'command': '{{ rsync_path }} {{ rsync_extra_parameters }} {{ rsync_user }}@{{ node_certs_generator_ip }}: {{ node_certs_source }}/{{ kibana_node_name }}/ {{ node_certs_destination }}/', 'when': ['not node_certs_generator', 'kibana_xpack_security', 'not certificate_file_exists.stat.exists'], 'tags': 'xpack-security'}]
# [{'command': '{{ rsync_path }} {{ rsync_extra_parameters }} {{ rsync_user }}@{{ node_certs_generator_ip }}: {{ node_certs_source }}/ca/ {{ node_certs_destination }}/', 'when': ['not node_certs_generator', 'kibana_xpack_security', 'not certificate_file_exists.stat.exists'], 'register': 'check_certs_permissions', 'tags': 'xpack-security'}]
# [{'shell': '/usr/share/kibana/bin/kibana-plugin install  https://packages.wazuh.com/wazuhapp/wazuhapp-{{ wazuh_version }}_{{ elastic_stack_version }}.zip', 'environment': {'NODE_OPTIONS': '--max-old-space-size=3072'}, 'args': {'executable': '/bin/bash', 'creates': '/usr/share/kibana/plugins/wazuh/package.json'}, 'notify': 'restart kibana', 'ignore_errors': '{{ kibana_plugin_install_ignore_error }}', 'tags': ['install', 'skip_ansible_lint']}]
# [{'service': {'name': 'kibana', 'enabled': True, 'state': 'started'}}]
# [{'command': '{{ rsync_path }} {{ rsync_extra_parameters }} {{ rsync_user }}@{{ node_certs_generator_ip }}: {{ node_certs_source }}/{{ filebeat_node_name }}/ {{ node_certs_destination }}/', 'when': ['not node_certs_generator', 'filebeat_xpack_security', 'not certificate_file_exists.stat.exists'], 'tags': 'xpack-security'}]
# [{'command': '{{ rsync_path }} {{ rsync_extra_parameters }} {{ rsync_user }}@{{ node_certs_generator_ip }}: {{ node_certs_source }}/ca/ {{ node_certs_destination }}/', 'when': ['not node_certs_generator', 'filebeat_xpack_security', 'not certificate_file_exists.stat.exists'], 'register': 'check_certs_permissions', 'tags': 'xpack-security'}]
# [{'shell': '/usr/share/elasticsearch/bin/elasticsearch-certutil cert --ca-key {{ node_certs_source }}/{{ ca_key_name }} --ca-cert {{ node_certs_source }}/{{ ca_cert_name }} --pem --in {{ node_certs_source }}/instances.yml --out {{ node_certs_source }}/certs.zip', 'when': ['node_certs_generator', 'not xpack_certs_zip.stat.exists', 'not generate_CA'], 'tags': 'xpack-security'}]
# [{'template': {'src': 'cdb_lists.j2', 'dest': '/var/ossec/etc/lists/{{ item.name }}', 'owner': 'root', 'group': 'ossec', 'mode': 416}, 'no_log': True, 'register': 'wazuh_manager_cdb_lists', 'until': 'wazuh_manager_cdb_lists is succeeded', 'notify': ['rebuild cdb_lists', 'restart wazuh-manager'], 'with_items': ['{{ cdb_lists }}'], 'when': ['cdb_lists is defined', 'cdb_lists is iterable'], 'tags': ['config']}]
# [{'service': {'name': '{{ item }}', 'enabled': True, 'state': 'started'}, 'with_items': ['wazuh-manager', 'wazuh-api'], 'tags': ['config'], 'environment': {'LD_LIBRARY_PATH': '$LD_LIBRARY_PATH:/var/ossec/framework/lib'}, 'when': ["not (ansible_distribution == 'CentOS' or ansible_distribution == 'RedHat' and ansible_distribution_major_version|int < 6)"]}]
# [{'service': {'name': 'wazuh-manager', 'enabled': True, 'state': 'started'}, 'tags': ['config'], 'when': ["ansible_distribution in ['CentOS', 'RedHat'] and ansible_distribution_major_version|int < 6"]}]
# [{'command': '{{ rsync_path }} {{ rsync_extra_parameters }} {{ rsync_user }}@{{ node_certs_generator_ip }}: {{ node_certs_source }}/{{ kibana_node_name }}/ {{ node_certs_destination }}/', 'when': ['not node_certs_generator', 'kibana_xpack_security', 'not certificate_file_exists.stat.exists'], 'tags': 'xpack-security'}]
# [{'command': '{{ rsync_path }} {{ rsync_extra_parameters }} {{ rsync_user }}@{{ node_certs_generator_ip }}: {{ node_certs_source }}/ca/ {{ node_certs_destination }}/', 'when': ['not node_certs_generator', 'kibana_xpack_security', 'not certificate_file_exists.stat.exists'], 'register': 'check_certs_permissions', 'tags': 'xpack-security'}]
# [{'shell': '/usr/share/kibana/bin/kibana-plugin install https://packages.wazuh.com/wazuhapp/wazuhapp-{{ wazuh_version }}_{{ elastic_stack_version }}.zip', 'environment': {'NODE_OPTIONS': '--max-old-space-size=3072'}, 'args': {'executable': '/bin/bash', 'creates': '/usr/share/kibana/plugins/wazuh/package.json'}, 'become': True, 'become_user': 'kibana', 'tags': ['install', 'skip_ansible_lint']}]
# [{'service': {'name': 'kibana', 'enabled': True, 'state': 'restarted'}}]
# [{'service': {'name': 'kibana', 'enabled': True, 'state': 'started'}}]
# [{'set_fact': {'wazuh_agent_win_path': '{% wazuh_winagent_config.install_dir_x86 if check_path.stat.exists else wazuh_winagent_config.install_dir %}'}}]
# [{'set_fact': 'correct_version=true', 'when': ['agent_version.stdout is defined', 'wazuh_winagent_config.version in agent_version.stdout']}]
# [{'shell': 'set -o pipefail\ncurl --silent --location https://rpm.nodesource.com/setup_8.x | bash -\n', 'args': {'warn': False, 'executable': '/bin/bash'}, 'when': ['ansible_distribution == "Amazon" and ansible_distribution_major_version == "NA"']}]
# [{'shell': 'set -o pipefail\ncurl --silent --location https://rpm.nodesource.com/setup_8.x | bash -\n', 'args': {'warn': False, 'executable': '/bin/bash', 'creates': '/etc/yum.repos.d/nodesource-el7.repo'}, 'when': ['ansible_distribution|lower == "amazon"']}]
# [{'become': True, 'shell': 'set -o pipefail\ncurl -s https://deb.nodesource.com/gpgkey/nodesource.gpg.key | apt-key add -\n', 'args': {'warn': False, 'executable': '/bin/bash'}, 'changed_when': False, 'when': ['ansible_distribution == "Ubuntu"', 'ansible_distribution_major_version | int == 14']}]
# [{'shell': 'set -o pipefail\ncurl --silent --location https://rpm.nodesource.com/setup_8.x | bash -\n', 'args': {'warn': False, 'executable': '/bin/bash', 'creates': '/etc/yum.repos.d/nodesource-el7.repo'}, 'when': ['ansible_distribution|lower == "amazon"']}]
# [{'shell': '/usr/share/kibana/bin/kibana-plugin install {{ wazuh_app_url }}-{{ wazuh_version }}_{{ elastic_stack_version }}.zip', 'environment': {'NODE_OPTIONS': '--max-old-space-size=3072'}, 'args': {'executable': '/bin/bash', 'creates': '/usr/share/kibana/plugins/wazuh/package.json'}, 'become': True, 'become_user': 'kibana', 'notify': 'restart kibana', 'tags': ['install', 'skip_ansible_lint']}]
# [{'command': 'sh /etc/nodejs.sh', 'register': 'nodejs_script', 'changed_when': 'nodejs_script.rc == 0', 'when': 'not node_service_status.stat.exists'}]
# [{'template': {'src': 'cdb_lists.j2', 'dest': '/var/ossec/etc/lists/{{ item.name }}', 'owner': 'root', 'group': 'ossec', 'mode': 416}, 'no_log': True, 'register': 'wazuh_manager_cdb_lists', 'until': 'wazuh_manager_cdb_lists is succeeded', 'notify': ['rebuild cdb_lists', 'restart wazuh-manager'], 'with_items': ['{{ cdb_lists }}'], 'when': ['cdb_lists is defined', 'cdb_lists is iterable'], 'tags': ['config']}]
# [{'service': {'name': '{{ item }}', 'enabled': True, 'state': 'started'}, 'with_items': ['wazuh-manager', 'wazuh-api'], 'tags': ['config'], 'environment': {'LD_LIBRARY_PATH': '$LD_LIBRARY_PATH:/var/ossec/framework/lib'}, 'when': ["not (ansible_distribution == 'CentOS' or ansible_distribution == 'RedHat' or ansible_distribution == 'Amazon')", 'ansible_distribution_major_version|int < 6']}]
# [{'service': {'name': 'wazuh-manager', 'enabled': True, 'state': 'started'}, 'tags': ['config'], 'when': ["ansible_distribution in ['CentOS', 'RedHat', 'Amazon'] and ansible_distribution_major_version|int < 6"]}]
# [{'template': {'src': 'wazuh.yml.j2', 'dest': '/usr/share/kibana/plugins/wazuh/wazuh.yml', 'owner': 'kibana', 'group': 'root', 'mode': 420}}]
# [{'shell': 'NODE_OPTIONS="{{node_options}}" /usr/share/kibana/bin/kibana --optimize --allow-root', 'args': {'executable': '/bin/bash'}, 'become': True, 'become_user': 'kibana'}]
# [{'copy': {'src': '/tmp/opendistro-nodecerts/config/{{ item }}', 'dest': '/etc/elasticsearch/', 'mode': 420}, 'with_items': ['root-ca.pem', 'root-ca.key', '{{ inventory_hostname }}.key', '{{ inventory_hostname }}.pem', '{{ inventory_hostname }}_http.key', '{{ inventory_hostname }}_http.pem', '{{ inventory_hostname }}_elasticsearch_config_snippet.yml', 'admin.key', 'admin.pem'], 'when': 'install.changed'}]
# [{'file': {'path': '{{ item }}', 'state': 'absent'}, 'with_items': ['{{opendistro_conf_path}}/kirk.pem', '{{opendistro_conf_path}}/kirk-key.pem', '{{opendistro_conf_path}}/esnode.pem', '{{opendistro_conf_path}}/esnode-key.pem'], 'when': 'install.changed'}]
# [{'file': {'path': '{{opendistro_conf_path}}/elasticsearch.yml', 'state': 'absent'}, 'when': 'install.changed'}]
# [{'template': {'src': 'templates/internal_users.yml.j2', 'dest': '{{ opendistro_sec_plugin_conf_path }}/internal_users.yml', 'mode': 420}, 'run_once': True, 'when': 'install.changed'}]
# [{'shell': "sed -i 's,{{ opendistro_admin_password }},'$(sh {{ opendistro_sec_plugin_tools_path }}/hash.sh -p {{ opendistro_admin_password }} | tail -1)',' {{ opendistro_sec_plugin_conf_path }}/internal_users.yml\n", 'run_once': True, 'when': 'install.changed'}]
# [{'shell': "sed -i 's,{{ opendistro_kibana_password }},'$(sh {{ opendistro_sec_plugin_tools_path }}/hash.sh -p {{ opendistro_kibana_password }} | tail -1)',' {{ opendistro_sec_plugin_conf_path }}/internal_users.yml\n", 'run_once': True, 'when': 'install.changed'}]
# [{'shell': "sh {{ opendistro_sec_plugin_tools_path }}/securityadmin.sh -cacert {{ opendistro_conf_path }}/root-ca.pem -cert {{ opendistro_conf_path }}/admin.pem -key {{ opendistro_conf_path }}/admin.key -cd {{ opendistro_sec_plugin_conf_path }}/ -nhnv -icl -h {{ hostvars[inventory_hostname]['ip'] }}\n", 'run_once': True, 'when': 'install.changed'}]
# [{'template': {'src': 'templates/jvm.options.j2', 'dest': '/etc/elasticsearch/jvm.options', 'owner': 'root', 'group': 'elasticsearch', 'mode': 420, 'force': True}, 'notify': 'restart elasticsearch', 'tags': 'opendistro'}]
# [{'shell': '/usr/share/kibana/node/bin/node {{ node_options }} /usr/share/kibana/src/cli --optimize', 'args': {'executable': '/bin/bash'}, 'become': True, 'become_user': 'kibana', 'changed_when': False, 'tags': ['skip_ansible_lint']}]
# [{'file': {'path': '/usr/share/kibana/optimize/wazuh/config/', 'state': 'directory', 'recurse': True, 'owner': 'kibana', 'group': 'kibana', 'mode': 489}, 'changed_when': False}]
# [{'template': {'src': 'sshd_config.j2', 'dest': '{{ sshd_config_file }}', 'owner': 'root', 'group': 'root', 'mode': 600}, 'notify': 'check and reload sshd'}]
# [{'command': '{{ sshd_binary }} -t', 'notify': 'reload sshd'}]
# [{'service': {'name': '{{ sshd_service }}', 'state': 'reloaded'}}]
# [{'template': {'src': 'sshd_config.j2', 'dest': '{{ sshd_config_file }}', 'owner': '{{ sshd_config_owner }}', 'group': '{{ sshd_config_group }}', 'mode': '{{ sshd_config_mode }}'}, 'notify': 'check and reload sshd', 'tags': ['sshd']}]
# [{'service': {'name': '{{ sshd_service }}', 'enabled': True, 'state': 'running'}, 'tags': ['sshd']}]
# [{'template': {'src': 'sshd_config.j2', 'dest': '{{ sshd_config_file }}', 'owner': '{{ sshd_config_owner }}', 'group': '{{ sshd_config_group }}', 'mode': '{{ sshd_config_mode }}', 'validate': '{{ sshd_binary }} -t -f %s'}, 'notify': 'reload_sshd', 'tags': ['sshd']}]
# [{'service': {'name': '{{ sshd_service }}', 'enabled': True, 'state': 'started'}, 'when': "sshd_manage_service and ansible_virtualization_type != 'docker'", 'tags': ['sshd']}]
# [{'set_fact': 'sshd_has_run=true', 'when': 'sshd_has_run is not defined', 'tags': ['sshd']}]
# [{'service': {'name': '{{ sshd_service }}', 'state': 'reloaded'}, 'when': "sshd_allow_reload and ansible_virtualization_type != 'docker'"}]

# %%
clean_tasks_df = clean_tasks_df.reset_index(drop=True)

# %%
clean_tasks_df['method_description'][3]
# Out:
# {'file': 'path=/opt/maven321 src=/opt/apache-maven-3.2.1 state=link'}

# %%
print(clean_tasks_df['task_name'][0])
clean_tasks_df['method_description'][0]
# Out:
# Copy download JDK7 script
# {'copy': 'src=download-jdk7.sh dest=/tmp mode=0555'}

# %%
clean_list[0]
# Out:
# {'copy': 'src=download-jdk7.sh dest=/tmp mode=0555',
#  'name': 'Copy download JDK7 script'}

# %%
with open('clean_stefano_tasks.pkl', 'wb') as output_file:
    pickle.dump(clean_tasks_df, output_file)

# %%
with open('clean_stefano_tasks.pkl', 'rb') as input_file:
    mapped10_stef_tasks = pickle.load(input_file)   
mapped10_stef_tasks.shape
# Out:
# (14187, 2)

# %%
print(mapped10_stef_tasks['task_name'][0])
mapped10_stef_tasks['method_description'][0]['copy']
# Out:
# Copy download JDK7 script
# 'src=download-jdk7.sh dest=/tmp mode=0555'

# %%
from ansible_modules import get_ansible_modules,top10_modules_used
from ident_ans_mods import identify_ansible_modules
from collections import Counter
from  itertools import chain
# %load_ext autoreload
# %autoreload 2

# %%
descriptions = mapped10_stef_tasks[['task_name','method_description']]

# %%
mda = get_ansible_modules('https://docs.ansible.com/ansible/2.8/modules/list_of_all_modules.html')

# %%
# mda

# %%
df_desc_mod = descriptions.copy()
df_desc_mod = df_desc_mod.reset_index()
df_desc_mod = df_desc_mod.rename(columns={'index':'repo_count'})
# df_desc_mod

# %%
inst = identify_ansible_modules(df_desc_mod,mda)

# %%
df = inst.create_text_cols()

# %%
df.head()
# Out:
#    repo_count  ... value_module_text
# 0           0  ...
# 1           1  ...
# 2           2  ...
# 3           3  ...
# 4           4  ...
#
# [5 rows x 7 columns]

# %%
df[df['mod_keys_found'].apply(len).gt(0)]
# Out:
#        repo_count  ...     value_module_text
# 0               0  ...
# 1               1  ...
# 2               2  ...
# 3               3  ...
# 4               4  ...
# ...           ...  ...                   ...
# 14182       14182  ...    {{ sshd_service }}
# 14183       14183  ...  Add or remove groups
# 14184       14184  ...    {{ sshd_service }}
# 14185       14185  ...
# 14186       14186  ...    {{ sshd_service }}
#
# [14187 rows x 7 columns]

# %%
df = df[df['mod_keys_found'].apply(len).gt(0)]

# %%
df = df.reset_index(drop=True)

# %%
tasks_ast_raw = deepcopy(df)

# %%
tasks_ast_raw = tasks_ast_raw[tasks_ast_raw['mod_keys_found'].apply(lambda v: len(set(v) & set(top10_list)) > 0)]

# %%
tasks_ast_raw.shape
# Out:
# (14187, 7)

# %%
tasks_10 = tasks_ast_raw.copy()

# %%
one_key_set = tasks_10[tasks_10['mod_keys_found'].apply(lambda x: len(x) < 2)]
one_key_set.shape
# Out:
# (14116, 7)

# %%
one_key_set = one_key_set.reset_index(drop=True)

# %%
counted_modules, counted_modules_df = top10_modules_used(one_key_set)
counted_modules
# Out:
# ['file',
#  'shell',
#  'set_fact',
#  'command',
#  'template',
#  'copy',
#  'service',
#  'fail',
#  'debug',
#  'gather_facts']

# %%
counted_modules_df.head(10)
# Out:
#   ansible_modules  frequency
# 4            file       2617
# 8           shell       2297
# 7        set_fact       2236
# 0         command       2200
# 9        template       2025
# 1            copy       1111
# 6         service        791
# 3            fail        503
# 2           debug        245
# 5    gather_facts         91

# %%
import sys
sys.path.insert(0,"/content/drive/My Drive/1_processing/w2v_cnn")

# %%
# !pip install treelib
# Out:
# Collecting treelib
#   Downloading treelib-1.6.1.tar.gz (24 kB)
# Requirement already satisfied: future in /usr/local/lib/python3.7/dist-packages (from treelib) (0.16.0)
# Building wheels for collected packages: treelib
#   Building wheel for treelib (setup.py) ... done
#   Created wheel for treelib: filename=treelib-1.6.1-py3-none-any.whl size=18386 sha256=17cbe58207c742e93b67f752cf87435bdfd688267fbed273185a385abf2f51c9
#   Stored in directory: /root/.cache/pip/wheels/89/be/94/2c6d949ce599d1443426d83ba4dc93cd35c0f4638260930a53
# Successfully built treelib
# Installing collected packages: treelib
# Successfully installed treelib-1.6.1

# %%
# !pip install anytree
# Out:
# Collecting anytree
#   Downloading anytree-2.8.0-py2.py3-none-any.whl (41 kB)
#      |████████████████████████████████| 41 kB 397 kB/s
# Requirement already satisfied: six>=1.9.0 in /usr/local/lib/python3.7/dist-packages (from anytree) (1.15.0)
# Installing collected packages: anytree
# Successfully installed anytree-2.8.0

# %%
from build_sequence_tokens import return_tokens, rem_nested_lists,convert_int_bool_to_str,tokenize_task,tokenize_name,is_empty

# %%
one_key_set['initial_ast'] = one_key_set['method_description'].apply(lambda x: return_tokens(x))
one_key_set['second_ast'] = one_key_set['initial_ast'].apply(lambda x: convert_int_bool_to_str(x))
one_key_set['third_ast'] = one_key_set['second_ast'].apply(lambda x: rem_nested_lists(x))

# %%
one_key_set['method_description'][0]
# Out:
# {'copy': 'src=download-jdk7.sh dest=/tmp mode=0555'}

# %%
import nltk
from nltk import word_tokenize
nltk.download('punkt')
# Out:
# [nltk_data] Downloading package punkt to /root/nltk_data...
# [nltk_data]   Unzipping tokenizers/punkt.zip.
# True

# %%
one_key_set = one_key_set.reset_index(drop=True)

# %%
task_name_tokens = []
except_list = []
for idx, tname in one_key_set['task_name'].items():
  try:
    task_name_tokens.append(word_tokenize(tname))
  except:
    except_list.append(idx)
    task_name_tokens.append('')

# %%
one_key_set['token_task_names'] = task_name_tokens

# %%
except_list
# Out:
# [11665, 11668, 11669]

# %%
type(one_key_set['token_task_names'][11665])
# Out:
# str

# %%
one_key_set.shape
# Out:
# (14116, 11)

# %%
one_key_set = one_key_set[one_key_set['token_task_names'] != '']
one_key_set.shape
# Out:
# (14113, 11)

# %%
one_key_set['token_task_names'][0]
# Out:
# ['Copy', 'download', 'JDK7', 'script']

# %%
mapped10 = deepcopy(one_key_set)

# %%
mapped10['first_tokens'] = mapped10['third_ast'].apply(lambda x: tokenize_task(x))

# %%
mapped10 = mapped10.reset_index(drop=True)

# %%
m10 = deepcopy(mapped10)

# %%
from pre_process import remove_symbols, remove_symbols_simple,flatten_list

# %%
m10['second_tokens'] = m10['first_tokens'].apply(lambda x: remove_symbols(x))
m10['third_tokens'] = m10['second_tokens'].apply(lambda x: flatten_list(x))

# %%
m10 = m10.drop(columns=['initial_ast', 'second_ast','first_tokens','second_tokens'])

# %%
m10['descr_one_string'] = m10['third_tokens'].apply(lambda x: ' '.join(x))

# %%
remove_list = [',', '``','"',"''",'==','{','}','(',"'",'[',']',"'==",')','>','=','-','|','/','+','$','.+',':','!',
               '--','\\','?','@',';','&','#','^','<','*','%','.','=~','{{','}}',]

def remove_symbols_simple(sequence):
  for item in sequence:
    if item in remove_list:
      sequence.remove(item)

  return sequence

# %%
m20 = deepcopy(m10)

# %%
m20['token_names_one_string'] = m20['token_task_names'].apply(lambda x: remove_symbols_simple(x))
m20['third_tokens'] = m20['third_tokens'].apply(lambda x: remove_symbols_simple(x))

# %%
m = deepcopy(m20)

# %%
m['token_task_names'] = m['token_task_names'].apply(lambda x: ['TaskName']+x)

# %%
def correct_first_token_name(seq):
  seq[0] = 'TaskDescription'
  return seq

# %%
mm = deepcopy(m)

# %%
mm['third_tokens'] = mm['third_tokens'].apply(lambda x: correct_first_token_name(x))

# %%
mm['token_task_names'][0]
# Out:
# ['TaskName', 'Copy', 'download', 'JDK7', 'script']

# %%
merged2 = deepcopy(mm)

# %%
merged2['task_com'] = merged2['token_task_names']+merged2['third_tokens']

# %%
def correct_first_token_name2(seq):
  seq.insert(0,'AnsibleTask')
  return seq

# %%
merged2['task_complete'] = merged2['task_com'].apply(lambda x: correct_first_token_name2(x))

# %%
merged2['task_complete'][0]
# Out:
# ['AnsibleTask',
#  'TaskName',
#  'Copy',
#  'download',
#  'JDK7',
#  'script',
#  'TaskDescription',
#  'copy',
#  'src=download-jdk7.sh',
#  'dest=/tmp',
#  'mode=0555']

# %%
merged2.to_pickle('val_set.pkl')

# %%
with open('val_set.pkl', 'rb') as input_file:
    val_set = pickle.load(input_file)   
val_set.columns
# Out:
# Index(['repo_count', 'task_name', 'method_description', 'mod_keys_found',
#        'mod_values_found', 'key_module_text', 'value_module_text', 'third_ast',
#        'token_task_names', 'third_tokens', 'descr_one_string',
#        'token_names_one_string', 'task_com', 'task_complete'],
#       dtype='object')

# %%
val_set.shape
# Out:
# (13754, 14)
